# %%
import graphlab
sales = graphlab.SFrame('~/ml_coursera/data/kc_house_data.gl')

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %%
train_data, test_data = sales.random_split(0.8, seed=0)

# %%
 model1_features = ['sqft_living', 'bedrooms', 'bathrooms', 'lat', 'long']

# %%
model1 = graphlab.linear_regression.create(train_data, target='price', features=model1_features, validation_set=None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 5
# Number of unpacked features : 5
# Number of coefficients    : 6
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# +-----------+----------+--------------+--------------------+---------------+
# | 1         | 2        | 1.104924     | 4074878.213096     | 236378.596455 |
# +-----------+----------+--------------+--------------------+---------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
model1_predictions = model1.predict(test_data)

# %%
print model1_predictions[0]
# Out:
# 471399.75997

# %%
from math import log

# %%
train_data['bedrooms_squared'] = train_data['bedrooms'].apply(lambda x: x**2)
test_data['bedrooms_squared'] = test_data['bedrooms'].apply(lambda x: x**2)

# %%
 train_data['bed_bath_rooms'] = train_data['bedrooms']*train_data['bathrooms']
test_data['bed_bath_rooms'] = test_data['bedrooms']*test_data['bathrooms']

# %%
train_data['bedrooms']*train_data['bedrooms']
# Out:
# dtype: float
# Rows: 17384
# [9.0, 9.0, 4.0, 16.0, 9.0, 16.0, 9.0, 9.0, 9.0, 9.0, 9.0, 4.0, 9.0, 25.0, 9.0, 16.0, 4.0, 9.0, 16.0, 9.0, 25.0, 4.0, 9.0, 9.0, 9.0, 9.0, 16.0, 4.0, 16.0, 16.0, 9.0, 16.0, 16.0, 16.0, 16.0, 25.0, 9.0, 9.0, 9.0, 9.0, 16.0, 9.0, 9.0, 9.0, 25.0, 9.0, 4.0, 25.0, 16.0, 9.0, 25.0, 16.0, 9.0, 9.0, 9.0, 9.0, 9.0, 16.0, 16.0, 9.0, 25.0, 25.0, 9.0, 16.0, 16.0, 16.0, 9.0, 9.0, 16.0, 9.0, 4.0, 9.0, 9.0, 9.0, 25.0, 9.0, 4.0, 4.0, 25.0, 9.0, 9.0, 9.0, 16.0, 16.0, 9.0, 9.0, 9.0, 9.0, 9.0, 9.0, 9.0, 9.0, 9.0, 4.0, 16.0, 16.0, 9.0, 9.0, 9.0, 9.0, ... ]

# %%
train_data
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
# 	bedrooms_squared	float
# 	bed_bath_rooms	float
#
# Rows: 17384
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %%
train_data['log_sqft_living'] = train_data['sqft_living'].apply(lambda x: log(x))
test_data['log_sqft_living'] = test_data['sqft_living'].apply(lambda x: log(x))

# %%
train_data
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
# 	bedrooms_squared	float
# 	bed_bath_rooms	float
# 	log_sqft_living	float
#
# Rows: 17384
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# ...

# %%
train_data['lat_plus_long'] = train_data['lat'] + train_data['long']
test_data['lat_plus_long'] = test_data['lat'] + test_data['long']

# %%
train_data
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
# 	bedrooms_squared	float
# 	bed_bath_rooms	float
# 	log_sqft_living	float
# 	lat_plus_long	float
#
# Rows: 17384
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# ...

# %%
test_data
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
# 	lat_plus_long	float
# 	log_sqft_living	float
# 	bed_bath_rooms	float
# 	bedrooms_squared	float
#
# Rows: 4229
#
# Data:
# +------------+---------------------------+----------+----------+-----------+
# |     id     |            date           |  price   | bedrooms | bathrooms |
# +------------+---------------------------+----------+----------+-----------+
# | 0114101516 | 2014-05-28 00:00:00+00:00 | 310000.0 |   3.0    |    1.0    |
# | 9297300055 | 2015-01-24 00:00:00+00:00 | 650000.0 |   4.0    |    3.0    |
# | 1202000200 | 2014-11-03 00:00:00+00:00 | 233000.0 |   3.0    |    2.0    |
# ...

# %%
model2_features = ['sqft_living', 'bedrooms', 'bathrooms', 'lat', 'long', 'bed_bath_rooms']

# %%
model2 = graphlab.linear_regression.create(train_data, target='price', features=model2_features, validation_set=None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 7
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# +-----------+----------+--------------+--------------------+---------------+
# | 1         | 2        | 0.070883     | 4014170.932927     | 235190.935428 |
# +-----------+----------+--------------+--------------------+---------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
model3_features = ['sqft_living', 'bedrooms', 'bathrooms', 'lat', 'long', 'bed_bath_rooms', 'bedrooms_squared', 
                   'log_sqft_living', 'lat_plus_long']

# %%
model3 = graphlab.linear_regression.create(train_data, target='price', features=model3_features, validation_set=None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 9
# Number of unpacked features : 9
# Number of coefficients    : 10
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# +-----------+----------+--------------+--------------------+---------------+
# | 1         | 2        | 0.035412     | 3193229.177894     | 228200.043155 |
# +-----------+----------+--------------+--------------------+---------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
test_data
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
# 	lat_plus_long	float
# 	log_sqft_living	float
# 	bed_bath_rooms	float
# 	bedrooms_squared	float
#
# Rows: 4229
#
# Data:
# +------------+---------------------------+----------+----------+-----------+
# |     id     |            date           |  price   | bedrooms | bathrooms |
# +------------+---------------------------+----------+----------+-----------+
# | 0114101516 | 2014-05-28 00:00:00+00:00 | 310000.0 |   3.0    |    1.0    |
# | 9297300055 | 2015-01-24 00:00:00+00:00 | 650000.0 |   4.0    |    3.0    |
# | 1202000200 | 2014-11-03 00:00:00+00:00 | 233000.0 |   3.0    |    2.0    |
# ...

# %%
test_bedrooms_squared_mean = round(test_data['bedrooms_squared'].mean(), 2)
# Out:
# 12.45

# %%
test_bed_bath_rooms_mean = round(test_data['bed_bath_rooms'].mean(), 2)

# %%
test_bed_bath_rooms_mean
# Out:
# 7.5

# %%
test_log_sqft_living_mean = round(test_data['log_sqft_living'].mean(), 2)

# %%
test_log_sqft_living_mean
# Out:
# 7.55

# %%
test_lat_plus_long_mean = round(test_data['lat_plus_long'].mean(), 2)

# %%
test_lat_plus_long_mean
# Out:
# -74.65

# %%
model1
# Out:
# Class                          : LinearRegression
#
# Schema
# ------
# Number of coefficients         : 6
# Number of examples             : 17384
# Number of feature columns      : 5
# Number of unpacked features    : 5
#
# Hyperparameters
# ---------------
# L1 penalty                     : 0.0
# L2 penalty                     : 0.01
#
# Training Summary
# ----------------
# Solver                         : newton
# Solver iterations              : 1
# Solver status                  : SUCCESS: Optimal solution found.
# Training time (sec)            : 1.1359
#
# Settings
# --------
# Residual sum of squares        : 9.71328233544e+14
# Training RMSE                  : 236378.5965
#
# Highest Positive Coefficients
# -----------------------------
# lat                            : 629865.7895
# bathrooms                      : 13811.8405
# sqft_living                    : 310.2633
#
# Lowest Negative Coefficients
# ----------------------------
# ...

# %%
model2
# Out:
# Class                          : LinearRegression
#
# Schema
# ------
# Number of coefficients         : 7
# Number of examples             : 17384
# Number of feature columns      : 6
# Number of unpacked features    : 6
#
# Hyperparameters
# ---------------
# L1 penalty                     : 0.0
# L2 penalty                     : 0.01
#
# Training Summary
# ----------------
# Solver                         : newton
# Solver iterations              : 1
# Solver status                  : SUCCESS: Optimal solution found.
# Training time (sec)            : 0.0969
#
# Settings
# --------
# Residual sum of squares        : 9.61592067856e+14
# Training RMSE                  : 235190.9354
#
# Highest Positive Coefficients
# -----------------------------
# lat                            : 625433.835
# bed_bath_rooms                 : 26961.6249
# sqft_living                    : 304.4493
#
# Lowest Negative Coefficients
# ----------------------------
# ...

# %%
model3
# Out:
# Class                          : LinearRegression
#
# Schema
# ------
# Number of coefficients         : 10
# Number of examples             : 17384
# Number of feature columns      : 9
# Number of unpacked features    : 9
#
# Hyperparameters
# ---------------
# L1 penalty                     : 0.0
# L2 penalty                     : 0.01
#
# Training Summary
# ----------------
# Solver                         : newton
# Solver iterations              : 1
# Solver status                  : SUCCESS: Optimal solution found.
# Training time (sec)            : 0.0528
#
# Settings
# --------
# Residual sum of squares        : 9.05276314555e+14
# Training RMSE                  : 228200.0432
#
# Highest Positive Coefficients
# -----------------------------
# lat                            : 704762.1484
# bathrooms                      : 65661.2072
# bedrooms                       : 28948.5277
# sqft_living                    : 529.1964
#
# Lowest Negative Coefficients
# ...

# %%
model1.evaluate(test_data)
# Out:
# {'max_error': 3950732.6883775964, 'rmse': 231462.44070022574}

# %%
model2.evaluate(test_data)
# Out:
# {'max_error': 3611744.7074824944, 'rmse': 230336.3019820938}

# %%
model3.evaluate(test_data)
# Out:
# {'max_error': 6279035.883126527, 'rmse': 244024.98958733617}
